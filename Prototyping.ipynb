# %% [markdown]
# ## Slurm Parsing

# %%
import csv
import glob
import os

from dataclasses import asdict

from cheeto.puppet import (PuppetGroupRecord,
                           PuppetUserRecord,
                           PuppetAccountMap,
                           PuppetGroupMap,
                           SlurmPartition, 
                           SlurmQOS, 
                           SlurmQOSTRES, 
                           SlurmRecord, 
                           parse_yaml_tree, 
                           MergeStrategy)

from cheeto.slurm import SAcctMgr
import sh
import yaml
from rich import print as pprint

# %%
def sacctmgr_show_parser(fp):
    return csv.DictReader(fp, delimiter='|')

# %%
def sanitize_tres(tres_string):
    if not tres_string:
        return {}
    tokens = tres_string.strip().split(',')
    tres = {}
    for token in tokens:
        resource, _, value = token.partition('=')
        resource = resource.removeprefix('gres/')
        resource, _, resource_type = resource.partition(':') # for now we discard the type from resource:type
        tres[resource] = value
    return tres

# %% [markdown]
# with open('slurm.qos.txt') as fp:
#     for row in sacctmgr_show_parser(fp):
#         print('Name={Name}, GrpTRES={GrpTRES}'.format(**row))
#         print(sanitize_tres(row['GrpTRES']))

# %%
def build_qos_map(qos_file_pointer, filter_on={'Name': 'normal'}):
    qos_map = {}
    filtered_map = {}
    for row in sacctmgr_show_parser(qos_file_pointer):
        
        filter_row = False
        for key, val in row.items():
            if filter_on.get(key, False) == val:
                filter_row = True
                break
    
        slurm_tres = sanitize_tres(row['GrpTRES'])
        puppet_tres = SlurmQOSTRES(cpus=slurm_tres.get('cpu', None),
                                   mem=slurm_tres.get('mem', None),
                                   gpus=slurm_tres.get('gpu', None))
        if puppet_tres.cpus is puppet_tres.mem is puppet_tres.gpus is None:
            puppet_tres = None
        puppet_qos = SlurmQOS(group=puppet_tres,
                              priority=row['Priority'])
        
        if filter_row:
            filtered_map[row['Name']] = puppet_qos
        else:
            qos_map[row['Name']] = puppet_qos
    return qos_map, filtered_map

# %%
with open('slurm.qos.txt') as fp:
    qos_map, filtered_map = build_qos_map(fp)
    #pprint(qos_map)
    #pprint(filtered_map)

# %%
qos_map
# Out:
# {'Name': SlurmQOS(group=None, job=None, priority='Priority'),
#  'zhougrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'zhougrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'zhougrpm': SlurmQOS(group=None, job=None, priority='80'),
#  'zhougrph': SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0'),
#  'jrigrpbm': SlurmQOS(group=None, job=None, priority='20'),
#  'jrigrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='980000M'), job=None, priority='20'),
#  'mahergrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'mahergrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus=None, mem='500000M'), job=None, priority='0'),
#  'adamgrpm': SlurmQOS(group=None, job=None, priority='10'),
#  'adamgrph': SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0'),
#  'jyllwgrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus=None, mem='500000M'), job=None, priority='0'),
#  'jyllwgrpbm': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='980000M'), job=None, priority='10'),
#  'weimergrph': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'weimergrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'runciegrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'runciegrph': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'schmittgrph': SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0'),
#  'schmittgrpm': SlurmQOS(group=None, job=None, priority='80'),
#  'rhijmansgrph': SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0'),
#  'rhijmansgrpm': SlurmQOS(group=None, job=None, priority='80'),
#  'pasternackgrph': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'pasternackgrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'millsgrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'millsgrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'millermrgrph': SlurmQOS(group=SlurmQOSTRES(cpus='168', gpus=None, mem='437.50G'), job=None, priority='0'),
#  'millermrgrpm': SlurmQOS(group=None, job=None, priority='70'),
#  'awhitehegrph': SlurmQOS(group=SlurmQOSTRES(cpus='120', gpus=None, mem='312.50G'), job=None, priority='0'),
#  'awhitehegrpm': SlurmQOS(group=None, job=None, priority='50'),
#  'paullricgrph': SlurmQOS(group=SlurmQOSTRES(cpus='1152', gpus=None, mem='3000G'), job=None, priority='0'),
#  'paullricgrpm': SlurmQOS(group=None, job=None, priority='480'),
#  'millermrgrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus=None, mem='500000M'), job=None, priority='0'),
#  'millermrgrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'latimergrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus=None, mem='500000M'), job=None, priority='0'),
#  'latimergrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'hastingsgrph': SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0'),
#  'hastingsgrpm': SlurmQOS(group=None, job=None, priority='80'),
#  'brnjohnsgrpbh': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus=None, mem='500000M'), job=None, priority='0'),
#  'brnjohnsgrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'admin': SlurmQOS(group=None, job=None, priority='0'),
#  'entnemgrpbt': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'entnemgrpbm': SlurmQOS(group=None, job=None, priority='10'),
#  'slupskygrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'slupskygrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'admingrph': SlurmQOS(group=SlurmQOSTRES(cpus='2048', gpus=None, mem=None), job=None, priority='0'),
#  'admingrpm': SlurmQOS(group=None, job=None, priority='0'),
#  'bennettgrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'bennettgrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'aigelgrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'aigelgrpm': SlurmQOS(group=None, job=None, priority='40'),
#  'cantubmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='500G'), job=None, priority='0'),
#  'millsgrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'millsgrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'cantugrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'qtlchenggrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='40'),
#  'qtlchenggrpm': SlurmQOS(group=None, job=None, priority='10'),
#  'qtlchenggrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'qtlchenggrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'ecl243h': SlurmQOS(group=SlurmQOSTRES(cpus='80', gpus=None, mem='500000M'), job=None, priority='0'),
#  'jrigrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='500G'), job=None, priority='0'),
#  'jrigrpm': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem=None), job=None, priority='20'),
#  'moniergrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'moniergrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'jinggrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'jingrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'donggrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='576', gpus=None, mem='6000000M'), job=None, priority='0'),
#  'donggrpbmm': SlurmQOS(group=None, job=None, priority='60'),
#  'agertongrpm': SlurmQOS(group=None, job=None, priority='20'),
#  'agertongrph': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='500G'), job=None, priority='0'),
#  'jingrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'jrigrph2': SlurmQOS(group=SlurmQOSTRES(cpus='640', gpus=None, mem='1500000M'), job=None, priority='0'),
#  'jrigrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'agertongrph2': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='500G'), job=None, priority='0'),
#  'agertongrpm2': SlurmQOS(group=None, job=None, priority='20'),
#  'jbondgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='1000G'), job=None, priority='0'),
#  'jbondgrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'dubcovskygrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='288', gpus=None, mem='3000G'), job=None, priority='0'),
#  'dubcovskygrpbmm': SlurmQOS(group=None, job=None, priority='30'),
#  'dubcovskygrpbigmemh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000G'), job=None, priority='0'),
#  'dubcovskygrpbigmemm': SlurmQOS(group=None, job=None, priority='20'),
#  'magertongrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='980000M'), job=None, priority='20'),
#  'magertongrpm2': SlurmQOS(group=None, job=None, priority='20'),
#  'knappgrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000G'), job=None, priority='0'),
#  'knappgrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'moniergrph2': SlurmQOS(group=SlurmQOSTRES(cpus='512', gpus=None, mem='2040000M'), job=None, priority='0'),
#  'moniergrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'bnbaileygpu': SlurmQOS(group=None, job=None, priority='0'),
#  'hastingsgrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'hastingsgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='10200000M'), job=None, priority='0'),
#  'ctbrowngrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='48', gpus=None, mem='500G'), job=None, priority='0'),
#  'ctbrowngrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'ctbrowngrp': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000G'), job=None, priority='0'),
#  'temph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='1000G'), job=None, priority='0'),
#  'diepenbrockgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='1000G'), job=None, priority='0'),
#  'diepenbrockgrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'sivasankargrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'runciegrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'ggg298bmh': SlurmQOS(group=SlurmQOSTRES(cpus='48', gpus=None, mem='500G'), job=None, priority='0'),
#  'ejf4grph2': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'ejf4grpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'sivasankargrph2': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250000M'), job=None, priority='10'),
#  'zimanyigrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'zimanyigrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'gmonroegrpbmm': SlurmQOS(group=None, job=None, priority='20'),
#  'ctbrowngrpm2': SlurmQOS(group=None, job=None, priority='20'),
#  'ctbrowngrph2': SlurmQOS(group=SlurmQOSTRES(cpus='224', gpus=None, mem='500G'), job=None, priority='0'),
#  'aigelgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='384', gpus=None, mem='750G'), job=None, priority='0'),
#  'aigelgrpm2': SlurmQOS(group=None, job=None, priority='30'),
#  'mldichtegrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'qtlchenggrpgpuh': SlurmQOS(group=SlurmQOSTRES(cpus='6', gpus='1', mem='96000M'), job=None, priority='0'),
#  'gpum': SlurmQOS(group=SlurmQOSTRES(cpus='60', gpus='10', mem='960G'), job=None, priority='0'),
#  'ctbrowngrpgpuh': SlurmQOS(group=SlurmQOSTRES(cpus='6', gpus='1', mem='96000M'), job=None, priority='0'),
#  'gquongrpgpuh': SlurmQOS(group=SlurmQOSTRES(cpus='18', gpus='3', mem='288000M'), job=None, priority='0'),
#  'jmearlesgrpgpuh': SlurmQOS(group=SlurmQOSTRES(cpus='6', gpus='1', mem='96000M'), job=None, priority='0'),
#  'qtlchenggrph2': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'qtlchenggrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'adamgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0'),
#  'adamgrpm2': SlurmQOS(group=None, job=None, priority='30'),
#  'rustyhgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='224', gpus=None, mem='500G'), job=None, priority='0'),
#  'rustyhgrpm2': SlurmQOS(group=None, job=None, priority='20'),
#  'runciegrph2': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='250G'), job=None, priority='0'),
#  'kerrigrph2': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'kerrigrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'gmonroegrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='3000000M'), job=None, priority='0'),
#  'marymgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None, priority='0'),
#  'marymgrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'slupskygrpbmm': SlurmQOS(group=None, job=None, priority='0'),
#  'zhougrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0'),
#  'zhougrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'jorgelmrgrpm2': SlurmQOS(group=None, job=None, priority='20'),
#  'jorgelmrgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='512', gpus=None, mem='1000G'), job=None, priority='0'),
#  'brannalagrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'brannalagrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'jbemersogrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500000M'), job=None, priority='0'),
#  'jbemersogrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'jbemersogrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='2000000M'), job=None, priority='0'),
#  'jbemersogrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'gpul': SlurmQOS(group=None, job=None, priority='0'),
#  'adamgrpbmm': SlurmQOS(group=None, job=None, priority='0'),
#  'fzdkeltgrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'fzdkeltgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'mldichtegrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'fvaldovigrph2': SlurmQOS(group=SlurmQOSTRES(cpus='1024', gpus=None, mem='2000000M'), job=None, priority='0'),
#  'fvaldovigrpm2': SlurmQOS(group=None, job=None, priority='40'),
#  'gittagrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'gittagrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'clswettgrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='1000000M'), job=None, priority='0'),
#  'clswettgrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'ctbrowngrp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='64', gpus='2', mem='250G'), job=None, priority='0'),
#  'hjzhou98grp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0'),
#  'gquongrp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0'),
#  'datalabgrp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0'),
#  'rhijmansgrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='2000000M'), job=None, priority='0'),
#  'rhijmansgrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'gmonroegrp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0'),
#  'geminigrp-gpu-a100-h': SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0'),
#  'datalabgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'datalabgrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'weimergrpbmh': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='2000000M'), job=None, priority='0'),
#  'weimergrpbmm': SlurmQOS(group=None, job=None, priority='10'),
#  'rbaygrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'rbaygrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'gmcoopgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'gmcoopgrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'gtaylorgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'gtaylorgrpm2': SlurmQOS(group=None, job=None, priority='10'),
#  'baskettgrph2': SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0'),
#  'baskettgrpm2': SlurmQOS(group=None, job=None, priority='10')}

# %%
def filter_nulls(d):
    return {key: val for key, val in d.items() if val}

def pprint_nonnull(d):
    pprint(filter_nulls(d))

# %%
with open('slurm.assoc.txt') as fp:
    for row in sacctmgr_show_parser(fp):
        assoc = {key: val for key, val in row.items() if val}
        #pprint(assoc)
        #print('User={User}, Account={Account}, Partition={Partition} QOS={QOS}'.format(**row))

# %%
def check_filter(d, filter_on):
    for key, val in d.items():
        if val in filter_on.get(key, []):
            return True
    return False

# %%
def sacctmgr_build_group_slurm_map(assoc_file_pointer,
                                   qos_map,
                                   filter_accounts_on={'Account': ['root', 'farm-test']},
                                   filter_users_on={'QOS': ['normal'],
                                                    'Partition': ['seriallcluster=farm']}):
    # map account => (partition, QOS)
    assoc_map = {'accounts': {}, 'users': {}}
    filtered_assocs = []
    for row in sacctmgr_show_parser(assoc_file_pointer):
        row = filter_nulls(row)
        #pprint(row)

        if 'Partition' not in row:
            # This is a parent Account definition, add it to the map.
            # Set partitions empty and fill in as we encounter them.
            
            filter_row = check_filter(row, filter_accounts_on)
            if filter_row:
                filtered_assocs.append(row)
            else:
                assoc_map['accounts'][row['Account']] = dict(
                    partitions = {},
                    max_jobs = row.get('MaxJobs', None)
                )
        elif 'User' in row:
            # partition<->QOS associations actually only exist per-user, but on our clusters,
            # they should always 
            filter_row = check_filter(row, filter_users_on)

            if filter_row:
                filtered_assocs.append(row)
            else:
                user_name = row['User']
                account_name = row['Account']
                partition_name = row['Partition']
                qos_name = row['QOS']

                try:
                    account_map = assoc_map['accounts'][account_name]
                except KeyError:
                    pprint(row)
                    pprint(filtered_assocs)
                    raise

                try:
                    qos = qos_map[qos_name]
                    print(qos)
                    if not qos:
                        qos = None
                    partition = SlurmPartition(
                        qos = qos
                    )
                except KeyError as e:
                    print(e)
                else:
                    if partition_name not in account_map['partitions']:
                        account_map['partitions'][partition_name] = partition

                    if user_name not in assoc_map['users']:
                        assoc_map['users'][user_name] = [partition]
                    else:
                        assoc_map['users'][user_name].append(partition)
                    
    # Now, convert to our structured dataclasses.
    for account_name, account_data in assoc_map['accounts'].items():
        assoc_map['accounts'][account_name] = SlurmRecord(
            account = account_name,
            max_jobs = account_data['max_jobs'],
            partitions = account_data['partitions']
        )

    return assoc_map, filtered_assocs

# %%
with open('slurm.assoc.txt') as fp:
    assoc_map, filtered_assocs = sacctmgr_build_group_slurm_map(fp, qos_map)
# Out:
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=None, job=None, priority='30')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# ...
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='32', gpus='1', mem='125G'), job=None, priority='0')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=None, job=None, priority='80')
# SlurmQOS(group=SlurmQOSTRES(cpus='96', gpus=None, mem='1000000M'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None, priority='0')
# SlurmQOS(group=None, job=None, priority='10')
# SlurmQOS(group=None, job=None, priority='10')

# %%
qos = assoc_map['accounts']['adamgrp'].partitions['high'].qos

# %%
files = glob.glob('/work/HPCCF/puppet.hpc-accounts/domains/farm.hpc.ucdavis.edu/*')
tree = parse_yaml_tree(files, merge_on=MergeStrategy.ALL)['merged-all']
puppet_mapping = PuppetAccountMap.Schema().load(tree)

# %%
import dataclasses

# %%
updated_puppet_groups = []
for slurm_account_name, slurm_account in assoc_map['accounts'].items():
    group = puppet_mapping.group.get(slurm_account_name, False)
    if not group:
        print('No match for Slurm account:', slurm_account_name)
        continue
    updated = dataclasses.replace(group, slurm=slurm_account)
    mapping = PuppetGroupMap(group={slurm_account_name: updated})
    updated_puppet_groups.append((slurm_account_name, mapping))
# Out:
# No match for Slurm account: admin
# No match for Slurm account: admingrp
# No match for Slurm account: agertongrp
# No match for Slurm account: billaccount
# No match for Slurm account: briangrp
# No match for Slurm account: cantugrp
# No match for Slurm account: emoniergrp
# No match for Slurm account: entnem
# No match for Slurm account: fzdkeltgrp
# No match for Slurm account: geminigrp
# No match for Slurm account: gpul
# No match for Slurm account: gquongrp
# No match for Slurm account: gtaylorgrp
# No match for Slurm account: imtiyazgrp
# No match for Slurm account: mldichtegrp
# No match for Slurm account: sivasankargrp
# No match for Slurm account: testing

# %%
pprint(updated_puppet_groups[:5])
# Out:
# [
#     (
#         'adamgrp',
#         PuppetGroupMap(
#             group={
#                 'adamgrp': PuppetGroupRecord(
#                     gid=9998,
#                     ensure='present',
#                     tag=None,
#                     storage=None,
#                     slurm=SlurmRecord(
#                         partitions={
#                             'high': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None)
#                             ),
#                             'low': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'med': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'med2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'low2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'high2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None)
#                             ),
#                             'bml': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             )
#                         },
#                         account='adamgrp',
#                         max_jobs='1024'
#                     )
#                 )
#             }
#         )
#     ),
#     (
#         'aigelgrp',
#         PuppetGroupMap(
#             group={
#                 'aigelgrp': PuppetGroupRecord(
#                     gid=1257289,
#                     ensure='present',
#                     tag=None,
#                     storage=[
#                         PuppetGroupStorage(
#                             name='aigelgrp',
#                             owner='aigel',
#                             autofs=PuppetAutofs(nas='nas-11-2-ib', path='/export/5/aigelgrp'),
#                             zfs=None
#                         ),
#                         PuppetGroupStorage(
#                             name='aigelgrp2',
#                             owner='aigel',
#                             autofs=PuppetAutofs(nas='nas-4-0-ib', path='/nas-4-0/aigelgrp2'),
#                             zfs=PuppetZFS(quota='10T')
#                         )
#                     ],
#                     slurm=SlurmRecord(
#                         partitions={
#                             'high2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='384', gpus=None, mem='750G'), job=None)
#                             ),
#                             'med2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'low2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'high': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None)
#                             ),
#                             'med': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'low': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             )
#                         },
#                         account='aigelgrp',
#                         max_jobs=None
#                     )
#                 )
#             }
#         )
#     ),
#     (
#         'awhitehegrp',
#         PuppetGroupMap(
#             group={
#                 'awhitehegrp': PuppetGroupRecord(
#                     gid=19204,
#                     ensure='present',
#                     tag=None,
#                     storage=[
#                         PuppetGroupStorage(
#                             name='awhitehegrp',
#                             owner='awhitehe',
#                             autofs=PuppetAutofs(nas='nas-12-2-ib', path='/nas-12-2/awhitehegrp/awhitehegrp'),
#                             zfs=PuppetZFS(quota='45.8T')
#                         ),
#                         PuppetGroupStorage(
#                             name='awhiteheroot2',
#                             owner='awhitehe',
#                             autofs=PuppetAutofs(nas='nas-4-1-ib', path='/nas-4-1/awhitehegrp2'),
#                             zfs=PuppetZFS(quota='20T')
#                         ),
#                         PuppetGroupStorage(
#                             name='awhitehegrp2',
#                             owner='awhitehe',
#                             autofs=PuppetAutofs(nas='nas-4-1-ib', path='/nas-4-1/awhitehegrp2/awhitehegrp2'),
#                             zfs=None
#                         )
#                     ],
#                     slurm=SlurmRecord(
#                         partitions={
#                             'high': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='120', gpus=None, mem='312.50G'), job=None)
#                             ),
#                             'low': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'med': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             )
#                         },
#                         account='awhitehegrp',
#                         max_jobs=None
#                     )
#                 )
#             }
#         )
#     ),
#     (
#         'baskettgrp',
#         PuppetGroupMap(
#             group={
#                 'baskettgrp': PuppetGroupRecord(
#                     gid=9996,
#                     ensure='present',
#                     tag=None,
#                     storage=None,
#                     slurm=SlurmRecord(
#                         partitions={
#                             'high2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='256', gpus=None, mem='500G'), job=None)
#                             ),
#                             'med2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'low2': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             )
#                         },
#                         account='baskettgrp',
#                         max_jobs=None
#                     )
#                 )
#             }
#         )
#     ),
#     (
#         'bennettgrp',
#         PuppetGroupMap(
#             group={
#                 'bennettgrp': PuppetGroupRecord(
#                     gid=12589,
#                     ensure='present',
#                     tag=None,
#                     storage=[
#                         PuppetGroupStorage(
#                             name='bennettroot2',
#                             owner='bsquared',
#                             autofs=PuppetAutofs(nas='nas-4-1-ib', path='/nas-4-1/bennettgrp2'),
#                             zfs=PuppetZFS(quota='15T')
#                         ),
#                         PuppetGroupStorage(
#                             name='bennettgrp',
#                             owner='bsquared',
#                             autofs=PuppetAutofs(nas='nas-4-1-ib', path='/nas-4-1/bennettgrp2/bennettgrp'),
#                             zfs=None
#                         )
#                     ],
#                     slurm=SlurmRecord(
#                         partitions={
#                             'low': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'med': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)
#                             ),
#                             'high': SlurmPartition(
#                                 qos=SlurmQOS(group=SlurmQOSTRES(cpus='128', gpus=None, mem='250G'), job=None)
#                             )
#                         },
#                         account='bennettgrp',
#                         max_jobs=None
#                     )
#                 )
#             }
#         )
#     )
# ]

# %%
dumper = PuppetGroupMap.Schema(only=['group.slurm'])
for group_name, group in updated_puppet_groups:
    path = f'/work/HPCCF/puppet.hpc-accounts/domains/farm.hpc.ucdavis.edu/{group_name}.slurm.yaml'
    with open(path, 'w') as fp:
        print(dumper.dumps(group), file=fp)

# %%
print(PuppetGroupMap.Schema(only=['group.slurm']).dumps(updated_puppet_groups[0][1]))
# Out:
# group:
#   adamgrp:
#     slurm:
#       partitions:
#         bml:
#           qos:
#             group: {}
#         high:
#           qos:
#             group:
#               cpus: 192
#               mem: 500G
#         high2:
#           qos:
#             group:
#               cpus: 352
#               mem: 762000M
#         low:
#           qos:
#             group: {}
#         low2:
#           qos:
#             group: {}
#         med:
#           qos:
#             group: {}
#         med2:
#           qos:
#             group: {}
#       account: adamgrp
#       max_jobs: 1024

# %%
updated_puppet_groups[0][1]
# Out:
# PuppetGroupMap(group={'adamgrp': PuppetGroupRecord(gid=9998, ensure='present', tag=None, storage=None, slurm=SlurmRecord(partitions={'high': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus='192', gpus=None, mem='500G'), job=None)), 'low': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)), 'med': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)), 'med2': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)), 'low2': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None)), 'high2': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus='352', gpus=None, mem='762000M'), job=None)), 'bml': SlurmPartition(qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None))}, account='adamgrp', max_jobs='1024'))})

# %%
assoc_map['gpul']
# Out:
# SlurmRecord(partitions={'gpul': SlurmPartition(name='gpul', qos=SlurmQOS(group=SlurmQOSTRES(cpus=None, gpus=None, mem=None), job=None))}, account='gpul', max_jobs=None)

# %%
user = PuppetUserRecord.Schema().load(tree['fmoore']['user']['fmoore'])

# %%
print(PuppetUserRecord.Schema().dumps(user))
# Out:
# fullname: Frances C Moore
# email: fmoore@ucdavis.edu
# uid: 1244121
# gid: 1244121
# groups:
# - adamgrp
# password: x
# shell: /bin/bash
# ensure: present
# storage:
#   zfs: false
#   autofs:
#     nas: nas-12-3-ib
#     path: /nas-12-3/adamgrp/4/

# %%
grp = PuppetGroupRecord.Schema().load(tree['dubcovskygrp']['group']['dubcovskygrp'])

# %%
assoc_map[]

# %%
import dataclasses

# %%
print(PuppetGroupRecordSchema.dumps(grp))

# %%
qos.to_slurm()
# Out:
# ['GrpCpus=192', 'GrpMem=500G']

# %%
sacctmgr = SAcctMgr(sacctmgr_path='/work/HPCCF/cheeto/sacctmgr')

# %%
sacctmgr.add_qos('testqos', assoc_map['adamgrp'].partitions['high'].qos)
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i add qos testqos GrpCpus=192 GrpMem=500G'>

# %%
sacctmgr.add_account('testaccount')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i add account testaccount'>

# %%
sacctmgr.modify_qos('testqos', qos)
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i modify qos testqos set GrpCpus=192 GrpMem=500G'>

# %%
sacctmgr.add_user('testuser', 'testaccount', 'testpartition', 'testqos')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i add user testuser account=testaccount partition=testpartition qos=testqos'>

# %%
sacctmgr.remove_user('testuser')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i remove user testuser'>

# %%
sacctmgr.remove_user('testuser', account_name='testaccount')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i remove user testuser account=testaccount'>

# %%
sacctmgr.remove_user('testuser', partition_name='testpartition')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i remove user testuser partition=testpartition'>

# %%
sacctmgr.remove_user('testuser', account_name='testaccount', partition_name='testpartition')
# Out:
# <Command '/work/HPCCF/cheeto/sacctmgr -i remove user testuser account=testaccount partition=testpartition'>
